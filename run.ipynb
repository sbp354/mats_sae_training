# %%
from transformer_lens import HookedTransformer
gelu = HookedTransformer.from_pretrained("gelu-2l")
# Out:
# Loaded pretrained model gelu-2l into HookedTransformer

# %%
# !pip install -q transformer_lens
# !pip install -q wandb

# %%
test_prompt = "Hi I am a test prompt for gelu-2l"
test_tokens = gelu.to_str_tokens(test_prompt)
_, cache = gelu.run_with_cache(test_tokens)

cache.cache_dict.keys()
# Out:
# dict_keys(['hook_embed', 'hook_pos_embed', 'blocks.0.hook_resid_pre', 'blocks.0.ln1.hook_scale', 'blocks.0.ln1.hook_normalized', 'blocks.0.attn.hook_q', 'blocks.0.attn.hook_k', 'blocks.0.attn.hook_v', 'blocks.0.attn.hook_attn_scores', 'blocks.0.attn.hook_pattern', 'blocks.0.attn.hook_z', 'blocks.0.hook_attn_out', 'blocks.0.hook_resid_mid', 'blocks.0.ln2.hook_scale', 'blocks.0.ln2.hook_normalized', 'blocks.0.mlp.hook_pre', 'blocks.0.mlp.hook_post', 'blocks.0.hook_mlp_out', 'blocks.0.hook_resid_post', 'blocks.1.hook_resid_pre', 'blocks.1.ln1.hook_scale', 'blocks.1.ln1.hook_normalized', 'blocks.1.attn.hook_q', 'blocks.1.attn.hook_k', 'blocks.1.attn.hook_v', 'blocks.1.attn.hook_attn_scores', 'blocks.1.attn.hook_pattern', 'blocks.1.attn.hook_z', 'blocks.1.hook_attn_out', 'blocks.1.hook_resid_mid', 'blocks.1.ln2.hook_scale', 'blocks.1.ln2.hook_normalized', 'blocks.1.mlp.hook_pre', 'blocks.1.mlp.hook_post', 'blocks.1.hook_mlp_out', 'blocks.1.hook_resid_post', 'ln_final.hook_scale', 'ln_final.hook_normalized'])

# %%
print(cache.cache_dict['blocks.1.attn.hook_z'].shape)
print(cache.cache_dict['blocks.0.hook_mlp_out'].shape)
# Out:
# torch.Size([13, 2, 8, 64])
# torch.Size([13, 2, 512])

# %%
from IPython import get_ipython
ipython = get_ipython()
ipython.run_line_magic("load_ext", "autoreload")
ipython.run_line_magic("autoreload", "2")

# %%
import torch
import os 

from sae_training.config import LanguageModelSAERunnerConfig
from sae_training.lm_runner import language_model_sae_runner

import cProfile


os.environ["TOKENIZERS_PARALLELISM"] = "false"
cfg = LanguageModelSAERunnerConfig(

    # Data Generating Function (Model + Training Distibuion)
    model_name = "gelu-2l",
    hook_point = "blocks.1.attn.hook_z",
    hook_point_layer = 2,
    d_in = 512,
    dataset_path = "NeelNanda/c4-tokenized-2b",
    is_dataset_tokenized=True,
    
    # SAE Parameters
    expansion_factor = 16,
    
    # Training Parameters
    lr = 1e-4,
    l1_coefficient = 0.000175,
    train_batch_size = 4096,
    context_size = 128,
    
    # Activation Store Parameters
    n_batches_in_buffer = 32,
    total_training_tokens = 1_000_000 * 20, 
    store_batch_size = 32,
    
    # Resampling protocol
    feature_sampling_method = 'l2',
    feature_sampling_window = 1000,
    feature_reinit_scale = 0.2,
    dead_feature_window=1000,
    dead_feature_threshold = 1e-6,
    
    # WANDB
    log_to_wandb = True,
    wandb_project= "mats_sae_training_gelu_2l",
    wandb_entity = None,
    wandb_log_frequency=10,
    
    # Misc
    device = "mps",
    seed = 42,
    n_checkpoints = 0,
    checkpoint_path = "checkpoints",
    dtype = torch.float32,
    )

def main():
    sparse_autoencoder = language_model_sae_runner(cfg)

# main()

import cProfile, pstats, io
from pstats import SortKey
pr = cProfile.Profile()
pr.enable()
# ... do something ...
main()
pr.disable()
s = io.StringIO()
sortby = SortKey.CUMULATIVE
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
# n_tokens_per_buffer (millions): 0.131072
# Lower bound: n_contexts_per_buffer (millions): 0.001024
# Total training steps: 4882
# n_dead_feature_samples: 3
# Loaded pretrained model gelu-2l into HookedTransformer
# Moving model to device:  mps
# Dataset is tokenized! Updating config.
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/Users/saraprice/Documents/Research/MATS/git/mats_sae_training/wandb/run-20231215_221225-j2dqzyii</code>
# Syncing run <strong><a href='https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l/runs/j2dqzyii' target="_blank">major-moon-11</a></strong> to <a href='https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l' target="_blank">https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l</a>
#  View run at <a href='https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l/runs/j2dqzyii' target="_blank">https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l/runs/j2dqzyii</a>
# 4882| MSE Loss 18.660 | L0 95.754: : 20000768it [19:54, 20932.50it/s]
# Saved model to checkpoints/lwd5u84h/final_sparse_autoencoder_gelu-2l_blocks.1.attn.hook_z_8192.pkl.gz
# VBox(children=(Label(value='29.532 MB of 29.532 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>details/n_training_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>losses/l1_loss</td><td>█▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>losses/mse_loss</td><td>█▆▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>losses/overall_loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/below_1e-5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/below_1e-6</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/ce_loss_with_ablation</td><td>▃▆▆▄▂▃▅▇▁▅█▅▄▅▁▃▃▄▃▄▃▁▄▃▂▅▂▄▃▂▇▅▅▄▅▄▅▃▇▅</td></tr><tr><td>metrics/ce_loss_with_sae</td><td>██▇▅▄▄▄▅▂▄▅▄▄▃▁▂▂▃▂▃▃▂▃▂▂▄▂▃▂▁▄▂▄▂▂▂▃▂▃▃</td></tr><tr><td>metrics/ce_loss_without_sae</td><td>▄▅▅▄▄▄▅█▃▄▆▅▅▃▁▃▃▅▄▅▄▃▅▃▃▇▃▄▃▂▇▄▆▃▄▄▅▄▅▅</td></tr><tr><td>metrics/current_learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/dead_features</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/l0</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/l2</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████████████████</td></tr><tr><td>metrics/l2_ratio</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████████</td></tr><tr><td>metrics/n_resampled_neurons</td><td>▁▁▁▁</td></tr><tr><td>metrics/reconstruction_score</td><td>▁▃▄▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>details/n_training_tokens</td><td>19988480</td></tr><tr><td>losses/l1_loss</td><td>12.567</td></tr><tr><td>losses/mse_loss</td><td>18.68985</td></tr><tr><td>losses/overall_loss</td><td>31.25686</td></tr><tr><td>metrics/below_1e-5</td><td>0.0</td></tr><tr><td>metrics/below_1e-6</td><td>0.0</td></tr><tr><td>metrics/ce_loss_with_ablation</td><td>6.84557</td></tr><tr><td>metrics/ce_loss_with_sae</td><td>4.26609</td></tr><tr><td>metrics/ce_loss_without_sae</td><td>4.11235</td></tr><tr><td>metrics/current_learning_rate</td><td>0.0001</td></tr><tr><td>metrics/dead_features</td><td>0.0</td></tr><tr><td>metrics/l0</td><td>96.75269</td></tr><tr><td>metrics/l2</td><td>9.04507</td></tr><tr><td>metrics/l2_ratio</td><td>0.85243</td></tr><tr><td>metrics/n_resampled_neurons</td><td>0</td></tr><tr><td>metrics/reconstruction_score</td><td>0.94375</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">major-moon-11</strong> at: <a href='https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l/runs/j2dqzyii' target="_blank">https://wandb.ai/sae_head_superposition/mats_sae_training_gelu_2l/runs/j2dqzyii</a><br/>Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231215_221225-j2dqzyii/logs</code>
#          215588549 function calls (192247731 primitive calls) in 1215.427 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 1215.427  607.713 /Users/saraprice/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3490(run_code)
#         2    0.000    0.000 1215.427  607.713 {built-in method builtins.exec}
#         1    0.000    0.000 1215.427 1215.427 /var/folders/rl/ypj4qwv94gb6k8wwdfnj6k3w0000gn/T/ipykernel_7861/3435447571.py:56(main)
#         1    0.001    0.001 1215.427 1215.427 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/lm_runner.py:12(language_model_sae_runner)
#         1    2.349    2.349 1195.053 1195.053 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/train_sae_on_language_model.py:17(train_sae_on_language_model)
#      4887    0.014    0.000  629.088    0.129 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:198(next_batch)
# 51649/46448    0.070    0.000  415.929    0.009 {built-in method builtins.next}
#      5192    0.076    0.000  376.251    0.072 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:625(__next__)
#      5192    3.937    0.001  375.860    0.072 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:672(_next_data)
#      4887    0.036    0.000  368.015    0.075 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:46(fetch)
#      4887    0.030    0.000  344.096    0.070 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:204(default_collate)
#      4887    0.033    0.000  344.066    0.070 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:87(collate)
#      4887    0.052    0.000  344.033    0.070 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/_utils/collate.py:153(collate_tensor_fn)
#      4887  343.977    0.070  343.977    0.070 {built-in method torch.stack}
#     34302  263.054    0.008  263.054    0.008 {method 'item' of 'torch._C._TensorBase' objects}
#      5056    1.509    0.000  256.838    0.051 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:33(get_batch_tokens)
#       306    6.764    0.022  253.627    0.829 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:170(get_data_loader)
#       307    6.317    0.021  248.192    0.808 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:134(get_buffer)
#     40543  201.259    0.005  201.259    0.005 {built-in method torch.tensor}
#      4883    0.055    0.000  178.144    0.036 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:433(backward)
#      4883    0.056    0.000  178.089    0.036 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:149(backward)
#      4883  176.855    0.036  176.855    0.036 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      9818    0.092    0.000   88.968    0.009 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:112(decorate_context)
#        48    0.007    0.000   84.418    1.759 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/train_sae_on_language_model.py:199(get_recons_loss)
# 352575/12259    0.254    0.000   53.382    0.004 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1514(_wrapped_call_impl)
# 352575/12259    0.667    0.000   53.357    0.004 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520(_call_impl)
#      5344    0.154    0.000   45.801    0.009 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:431(forward)
#      4912    0.980    0.000   43.953    0.009 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:111(get_activations)
#      4912    0.047    0.000   42.970    0.009 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:617(run_with_cache)
#      4912    0.038    0.000   42.916    0.009 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:420(run_with_cache)
#     10688    2.886    0.000   42.912    0.004 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:1128(forward)
#    485682   39.248    0.000   39.248    0.000 {built-in method torch.cat}
#     20225    0.102    0.000   37.685    0.002 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py:969(__iter__)
#     20225    0.044    0.000   26.309    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py:727(_apply_feature_types_on_example)
#     20225    0.030    0.000   26.149    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1812(encode_example)
# 20750850/20225    8.779    0.000   25.624    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1211(encode_nested_example)
#     20225    0.030    0.000   25.589    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1223(<dictcomp>)
#     20225    3.936    0.000   25.386    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1273(<listcomp>)
#      4887   23.881    0.005   23.881    0.005 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51(<listcomp>)
#     43184    8.081    0.000   18.044    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:251(forward)
#     10688    4.044    0.000   16.904    0.002 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:516(forward)
#      4883    0.034    0.000   15.024    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:63(wrapper)
#      4883    0.200    0.000   14.990    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:356(wrapper)
#     78531   14.682    0.000   14.682    0.000 {method 'acquire' of '_thread.lock' objects}
#      4883    0.088    0.000   14.019    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:58(_use_grad)
#      4883    0.090    0.000   13.908    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/adam.py:130(step)
#      9815    0.031    0.000   13.716    0.001 /Users/saraprice/anaconda3/lib/python3.11/threading.py:288(wait)
#      4883    0.050    0.000   13.683    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/adam.py:254(adam)
#      9822    0.027    0.000   13.649    0.001 /Users/saraprice/anaconda3/lib/python3.11/threading.py:604(wait)
#      4883    2.605    0.001   13.489    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/adam.py:330(_single_tensor_adam)
#    105764    0.604    0.000   12.221    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/functional.py:190(einsum)
#    105764   11.486    0.000   11.486    0.000 {built-in method torch.einsum}
#     16/10    0.000    0.000   10.485    1.049 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:249(wait)
#        25    0.000    0.000   10.475    0.419 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:128(_get_and_clear)
#        25    0.000    0.000   10.475    0.419 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:125(_wait)
#     85936    0.127    0.000   10.467    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:127(einsum)
#  20710400    6.561    0.000    9.337    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:502(encode_example)
#     85936    0.055    0.000    9.269    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:53(einsum)
#     20225    0.023    0.000    8.853    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py:115(__iter__)
#     20225    0.290    0.000    8.830    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py:799(wrapper)
#   549/548    0.004    0.000    8.813    0.016 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:335(wrapper)
#       545    0.006    0.000    8.689    0.016 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:389(wrapper)
#         1    0.000    0.000    8.503    8.503 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:4079(finish)
#         1    0.000    0.000    8.503    8.503 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1939(finish)
#         1    0.000    0.000    8.503    8.503 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1955(_finish)
#         1    0.000    0.000    8.393    8.393 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2193(_atexit_cleanup)
#         1    0.000    0.000    8.386    8.386 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2434(_on_finish)
#      5031    3.347    0.001    7.978    0.002 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/sparse_autoencoder.py:69(forward)
#         1    0.000    0.000    7.279    7.279 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/utils.py:23(load_session)
#         1    0.000    0.000    6.103    6.103 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/utils.py:69(get_activations_loader)
#         1    0.000    0.000    6.103    6.103 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/activations_store.py:13(__init__)
#    108013    6.001    0.000    6.001    0.000 {method 'mean' of 'torch._C._TensorBase' objects}
#      9767    0.035    0.000    5.560    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1322(refresh)
#      9767    0.036    0.000    5.426    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1461(display)
#      9767    0.023    0.000    4.781    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:345(print_status)
#     10688    1.537    0.000    4.779    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:956(forward)
#         3    0.000    0.000    4.686    1.562 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/formatting/formatting.py:440(format_batch)
#         3    0.001    0.000    4.686    1.562 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/formatting/formatting.py:149(extract_batch)
#         3    4.685    1.562    4.685    1.562 {method 'to_pydict' of 'pyarrow.lib.Table' objects}
#      9767    0.017    0.000    4.484    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:339(fp_write)
#     19534    0.027    0.000    4.467    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/utils.py:125(inner)
# 86327379/85785528    3.746    0.000    4.012    0.000 {built-in method builtins.isinstance}
#      5192    0.003    0.000    3.909    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:619(_next_index)
#      5192    2.154    0.000    3.898    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/sampler.py:269(__iter__)
#         3    2.682    0.894    3.763    1.254 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/packaged_modules/parquet/parquet.py:58(_generate_tables)
#     62716    3.642    0.000    3.642    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#      4883    0.022    0.000    3.474    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1379(set_description)
#       288    0.003    0.000    3.284    0.011 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:327(run_with_hooks)
#         1    0.000    0.000    3.269    3.269 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:934(init)
#         1    0.001    0.001    3.247    3.247 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:561(init)
#     19828    0.131    0.000    3.240    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/einops.py:826(einsum)
#     48219    3.118    0.000    3.118    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#     19828    0.048    0.000    3.056    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/_backends.py:286(einsum)
#      4883    0.638    0.000    2.550    0.001 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/sparse_autoencoder.py:189(remove_gradient_parallel_to_decoder_directions)
#     40450    0.061    0.000    2.421    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/arrow_dataset.py:185(features)
#      9787    0.057    0.000    2.417    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py:547(flush)
#     40450    0.050    0.000    2.360    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1929(copy)
# 860269/51194    0.800    0.000    2.325    0.000 /Users/saraprice/anaconda3/lib/python3.11/copy.py:128(deepcopy)
#     19532    2.269    0.000    2.269    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#      4883    0.033    0.000    2.161    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1195(update)
# 161806/40452    0.285    0.000    2.044    0.000 /Users/saraprice/anaconda3/lib/python3.11/copy.py:259(_reconstruct)
#      9769    0.022    0.000    2.034    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/redirect.py:639(write)
#     24874    1.960    0.000    1.960    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#     19532    1.902    0.000    1.902    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#     21376    1.892    0.000    1.892    0.000 {built-in method torch.where}
#     10314    0.021    0.000    1.887    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:368(wrapper_fn)
#     19532    1.855    0.000    1.855    0.000 {method 'lerp_' of 'torch._C._TensorBase' objects}
# 323612/80906    0.053    0.000    1.761    0.000 /Users/saraprice/anaconda3/lib/python3.11/copy.py:264(<genexpr>)
#     10400    0.040    0.000    1.746    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:271(hooks)
#  20017457    1.176    0.000    1.744    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/data/sampler.py:149(__iter__)
#     19532    1.732    0.000    1.732    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
# 121363/40459    0.177    0.000    1.684    0.000 /Users/saraprice/anaconda3/lib/python3.11/copy.py:227(_deepcopy_dict)
#      5344    0.619    0.000    1.634    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:228(input_to_embed)
#     19532    1.593    0.000    1.593    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#      9767    0.014    0.000    1.592    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2163(<lambda>)
#     10155    0.036    0.000    1.575    0.000 /Users/saraprice/anaconda3/lib/python3.11/contextlib.py:141(__exit__)
#      9769    0.038    0.000    1.557    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1480(_console_raw_callback)
#  20710400    1.530    0.000    1.530    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/pyarrow/types.py:57(is_boolean)
#      9769    0.108    0.000    1.516    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:625(publish_output_raw)
#      5200    0.009    0.000    1.495    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:200(reset_hooks)
#      5200    0.094    0.000    1.474    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:188(remove_all_hook_fns)
#        10    0.000    0.000    1.462    0.146 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:502(request)
#    260000    0.316    0.000    1.374    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:104(remove_hooks)
#      4884    0.046    0.000    1.352    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_compile.py:20(inner)
#     14650    0.177    0.000    1.329    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/functional.py:1480(norm)
#  20710400    1.246    0.000    1.246    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/pyarrow/types.py:68(is_integer)
#     10330    0.029    0.000    1.245    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:49(_publish)
#      9769    0.030    0.000    1.241    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:76(_publish_output_raw)
#      4883    0.509    0.000    1.235    0.000 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/sparse_autoencoder.py:185(set_decoder_norm_to_unit_norm)
#     10330    0.030    0.000    1.206    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:218(send_record_publish)
#         1    0.005    0.005    1.171    1.171 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/utils.py:49(get_model)
#     10335    0.006    0.000    1.167    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154(send_server_request)
#         1    0.000    0.000    1.165    1.165 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:1067(from_pretrained)
#      4883    0.037    0.000    1.161    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:56(_make_grads)
#     10335    0.072    0.000    1.161    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:145(_send_message)
#     10688    0.188    0.000    1.157    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:675(apply_causal_mask)
#     14650    1.122    0.000    1.122    0.000 {built-in method torch.frobenius_norm}
#         1    0.002    0.002    1.120    1.120 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/sparse_autoencoder.py:208(save_model)
#     10688    0.015    0.000    1.119    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:1826(softmax)
#      4883    1.119    0.000    1.119    0.000 {built-in method torch.ones_like}
#      17/1    0.003    0.000    1.113    1.113 {built-in method _pickle.dump}
#        10    0.000    0.000    1.103    0.110 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:673(send)
#     10688    1.102    0.000    1.102    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#         5    0.000    0.000    1.061    0.212 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:62(sync)
#         4    0.000    0.000    1.061    0.265 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:112(wrapper)
#         5    0.000    0.000    1.051    0.210 /Users/saraprice/anaconda3/lib/python3.11/gzip.py:272(write)
#         5    1.045    0.209    1.045    0.209 {method 'compress' of 'zlib.Compress' objects}
#     10335    0.027    0.000    1.040    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:121(_sendall_with_error_handle)
#     39170    0.016    0.000    1.029    0.000 /Users/saraprice/anaconda3/lib/python3.11/threading.py:1118(_wait_for_tstate_lock)
#     10340    1.011    0.000    1.011    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    1.002    1.002 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/backend/backend.py:226(cleanup)
#         1    0.000    0.000    1.002    1.002 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:530(join)
#         1    0.000    0.000    1.002    1.002 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/router.py:98(join)
#         4    0.001    0.000    1.001    0.250 /Users/saraprice/anaconda3/lib/python3.11/threading.py:1080(join)
#    540945    0.455    0.000    0.985    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1697(__setattr__)
#     14958    0.052    0.000    0.979    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/profiler.py:630(__enter__)
#     14958    0.019    0.000    0.927    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_ops.py:687(__call__)
#        10    0.000    0.000    0.915    0.092 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/adapters.py:434(send)
#        10    0.000    0.000    0.911    0.091 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:533(urlopen)
#     14958    0.908    0.000    0.908    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#        10    0.000    0.000    0.899    0.090 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:378(_make_request)
#     85936    0.275    0.000    0.886    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:76(convert_equation)
#     10688    0.854    0.000    0.854    0.000 {built-in method torch.isnan}
#     21292    0.808    0.000    0.808    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#     51/32    0.000    0.000    0.799    0.025 /Users/saraprice/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:102(_inner_fn)
#     10062    0.749    0.000    0.749    0.000 {built-in method torch.abs}
#      4884    0.048    0.000    0.748    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_dynamo/decorators.py:33(disable)
#     10688    0.746    0.000    0.746    0.000 {built-in method torch._C._nn.gelu}
#         1    0.000    0.000    0.700    0.700 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:1544(load_dataset)
#         1    0.000    0.000    0.699    0.699 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:1405(load_dataset_builder)
#         1    0.000    0.000    0.696    0.696 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:1047(dataset_module_factory)
#         2    0.000    0.000    0.690    0.345 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/utils.py:44(download_file_from_hf)
#      5344    0.666    0.000    0.670    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:39(forward)
#         2    0.000    0.000    0.649    0.325 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/download/streaming_download_manager.py:368(read_with_retries)
#         2    0.000    0.000    0.649    0.325 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/implementations/http.py:579(read)
#         2    0.000    0.000    0.649    0.324 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1683(read)
#         2    0.003    0.001    0.649    0.324 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/caching.py:349(_fetch)
#      4884    0.112    0.000    0.631    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:267(__call__)
#         3    0.000    0.000    0.610    0.203 /Users/saraprice/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:956(hf_hub_download)
#         3    0.000    0.000    0.603    0.201 /Users/saraprice/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1500(get_hf_file_metadata)
#       6/3    0.000    0.000    0.603    0.201 /Users/saraprice/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:358(_request_wrapper)
#         3    0.000    0.000    0.603    0.201 /Users/saraprice/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:114(http_backoff)
#      9767    0.044    0.000    0.602    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1147(__str__)
#         3    0.000    0.000    0.564    0.188 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/file_utils.py:408(http_head)
#         3    0.000    0.000    0.563    0.188 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/file_utils.py:293(_request_with_retry)
#         3    0.000    0.000    0.563    0.188 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/api.py:14(request)
#      4884    0.056    0.000    0.558    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:307(_fn)
#        12    0.000    0.000    0.533    0.044 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/utils.py:764(should_bypass_proxies)
#        12    0.000    0.000    0.533    0.044 /Users/saraprice/anaconda3/lib/python3.11/urllib/request.py:2649(proxy_bypass)
#        12    0.000    0.000    0.530    0.044 /Users/saraprice/anaconda3/lib/python3.11/urllib/request.py:2635(proxy_bypass_macosx_sysconf)
#        12    0.000    0.000    0.528    0.044 /Users/saraprice/anaconda3/lib/python3.11/urllib/request.py:2567(_proxy_bypass_macosx_sysconf)
#        12    0.528    0.044    0.528    0.044 {built-in method _socket.gethostbyname}
#     29376    0.093    0.000    0.501    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py:243(schedule)
#       222    0.039    0.000    0.500    0.002 {method 'readline' of '_io.BufferedReader' objects}
#     20225    0.028    0.000    0.495    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:419(cast_to_python_objects)
#        10    0.000    0.000    0.467    0.047 /Users/saraprice/anaconda3/lib/python3.11/http/client.py:1334(getresponse)
# 60675/20225    0.336    0.000    0.467    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:263(_cast_to_python_objects)
#        10    0.000    0.000    0.464    0.046 /Users/saraprice/anaconda3/lib/python3.11/http/client.py:311(begin)
#        15    0.000    0.000    0.463    0.031 /Users/saraprice/anaconda3/lib/python3.11/socket.py:692(readinto)
#        15    0.000    0.000    0.463    0.031 /Users/saraprice/anaconda3/lib/python3.11/ssl.py:1300(recv_into)
#        15    0.000    0.000    0.463    0.031 /Users/saraprice/anaconda3/lib/python3.11/ssl.py:1158(read)
#        15    0.463    0.031    0.463    0.031 {method 'read' of '_ssl._SSLSocket' objects}
#        10    0.000    0.000    0.462    0.046 /Users/saraprice/anaconda3/lib/python3.11/http/client.py:278(_read_status)
#      4884    0.078    0.000    0.454    0.000 /Users/saraprice/anaconda3/lib/python3.11/inspect.py:936(getsourcefile)
#      1224    0.447    0.000    0.447    0.000 {built-in method torch.randperm}
#         1    0.000    0.000    0.445    0.445 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/loading_from_pretrained.py:982(get_pretrained_state_dict)
#      5031    0.010    0.000    0.438    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:1460(relu)
#      4883    0.079    0.000    0.436    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:776(zero_grad)
#      9767    0.194    0.000    0.436    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:352(format_meter)
#        10    0.000    0.000    0.429    0.043 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1045(_validate_conn)
#         5    0.000    0.000    0.429    0.086 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:361(connect)
#      5031    0.427    0.000    0.427    0.000 {built-in method torch.relu}
#      9777    0.040    0.000    0.419    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py:610(write)
#         1    0.000    0.000    0.411    0.411 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:759(get_module)
#       663    0.381    0.001    0.381    0.001 {method 'tolist' of 'torch._C._TensorBase' objects}
#      9777    0.012    0.000    0.362    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py:532(_schedule_flush)
#      5200    0.021    0.000    0.362    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:64(full_hook)
#     14958    0.161    0.000    0.357    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/profiler.py:636(__exit__)
#        11    0.000    0.000    0.356    0.032 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/utils.py:824(get_environ_proxies)
#         4    0.010    0.002    0.354    0.089 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/sparse_autoencoder.py:102(resample_neurons)
#        10    0.000    0.000    0.354    0.035 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:751(merge_environment_settings)
#         1    0.000    0.000    0.349    0.349 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/download/streaming_download_manager.py:865(__iter__)
#         1    0.000    0.000    0.349    0.349 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/download/streaming_download_manager.py:935(_iter_from_urlpaths)
#         1    0.000    0.000    0.349    0.349 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/download/streaming_download_manager.py:253(xisfile)
#     29376    0.338    0.000    0.338    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py:543(send)
#         1    0.000    0.000    0.337    0.337 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/loading_from_pretrained.py:811(get_pretrained_model_config)
#    552833    0.337    0.000    0.337    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1682(__getattr__)
#         1    0.000    0.000    0.336    0.336 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/loading_from_pretrained.py:770(convert_neel_model_config)
#         8    0.332    0.041    0.332    0.041 {built-in method torch.nonzero}
#         2    0.000    0.000    0.323    0.162 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/file_utils.py:150(cached_path)
#      4883    0.319    0.000    0.319    0.000 {method 'abs' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.318    0.159 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/file_utils.py:436(get_from_cache)
#       432    0.003    0.000    0.306    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:591(loss_fn)
#       432    0.054    0.000    0.303    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/utils.py:121(lm_cross_entropy_loss)
#   3549552    0.290    0.000    0.290    0.000 {method 'get' of 'dict' objects}
#       144    0.003    0.000    0.285    0.002 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/train_sae_on_language_model.py:233(replacement_hook)
#      9767    0.015    0.000    0.270    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/utils.py:309(disp_len)
#     85959    0.257    0.000    0.257    0.000 {method 'findall' of 're.Pattern' objects}
#      5344    0.048    0.000    0.253    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:87(forward)
#    161831    0.222    0.000    0.251    0.000 {method '__reduce_ex__' of 'object' objects}
#     69577    0.250    0.000    0.250    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#      5129    0.015    0.000    0.250    0.000 <frozen genericpath>:16(exists)
#         1    0.000    0.000    0.248    0.248 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:742(__init__)
#         1    0.000    0.000    0.248    0.248 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:156(increase_load_count)
#         1    0.000    0.000    0.246    0.246 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/file_utils.py:94(head_hf_s3)
#     10265    0.076    0.000    0.245    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/einops.py:459(reduce)
#     10155    0.011    0.000    0.242    0.000 /Users/saraprice/anaconda3/lib/python3.11/contextlib.py:132(__enter__)
#      9767    0.011    0.000    0.241    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/utils.py:305(_text_width)
#    540913    0.169    0.000    0.237    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/parameter.py:8(__instancecheck__)
#      5269    0.236    0.000    0.236    0.000 {built-in method posix.stat}
# 93393/93386    0.109    0.000    0.230    0.000 {method 'join' of 'str' objects}
#      9767    0.052    0.000    0.229    0.000 {built-in method builtins.sum}
#         5    0.000    0.000    0.222    0.044 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:355(ssl_wrap_socket)
#       432    0.067    0.000    0.218    0.001 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/components.py:63(forward)
#     10698    0.216    0.000    0.216    0.000 {built-in method torch.zeros_like}
#      9818    0.068    0.000    0.204    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:141(clone)
#    161792    0.203    0.000    0.203    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#     40452    0.095    0.000    0.201    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1573(__init__)
#         5    0.000    0.000    0.200    0.040 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:161(_new_conn)
#         5    0.000    0.000    0.200    0.040 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/util/connection.py:37(create_connection)
#         9    0.002    0.000    0.194    0.022 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1054(to)
#         5    0.194    0.039    0.194    0.039 {method 'connect' of '_socket.socket' objects}
#         1    0.000    0.000    0.194    0.194 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:1051(move_model_modules_to_device)
#     14958    0.022    0.000    0.193    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/_ops.py:447(__call__)
#     130/9    0.004    0.000    0.192    0.021 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:807(_apply)
# 603799/602992    0.183    0.000    0.192    0.000 {built-in method builtins.getattr}
#      5200    0.037    0.000    0.189    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:53(add_hook)
#         3    0.000    0.000    0.187    0.062 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:593(get)
#     20224    0.046    0.000    0.186    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1133(bos_token_id)
#        64    0.000    0.000    0.186    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1154(convert)
#     85936    0.110    0.000    0.186    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:8(get_backend)
#        11    0.000    0.000    0.183    0.017 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:159(resolve_redirects)
#         1    0.000    0.000    0.183    0.183 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:303(rebuild_proxies)
#         1    0.000    0.000    0.183    0.183 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/utils.py:862(resolve_proxies)
#    952739    0.120    0.000    0.178    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/utils.py:306(<genexpr>)
#     80900    0.101    0.000    0.177    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/py_utils.py:298(zip_dict)
#       544    0.004    0.000    0.172    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1619(log)
#     14958    0.171    0.000    0.171    0.000 {built-in method torch._ops.profiler.}
#       544    0.016    0.000    0.168    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1583(_log)
#     10265    0.040    0.000    0.149    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/einops.py:229(_apply_recipe)
#       544    0.008    0.000    0.142    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1454(_partial_history_callback)
#         1    0.000    0.000    0.135    0.135 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/serialization.py:856(load)
#      4883    0.053    0.000    0.133    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:109(_default_to_fused_or_foreach)
#    242721    0.108    0.000    0.133    0.000 /Users/saraprice/anaconda3/lib/python3.11/copy.py:243(_keep_alive)
#         1    0.000    0.000    0.132    0.132 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1317(_load)
#      5344    0.010    0.000    0.131    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/einops.py:594(repeat)
#      4912    0.009    0.000    0.130    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/einops/einops.py:536(rearrange)
#       544    0.025    0.000    0.130    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:538(publish_partial_history)
#    407872    0.117    0.000    0.130    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:94(try_make_abbr)
#         1    0.003    0.003    0.129    0.129 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2835(log_artifact)
#         1    0.000    0.000    0.128    0.128 {method 'load' of '_pickle.Unpickler' objects}
#         5    0.000    0.000    0.127    0.025 /Users/saraprice/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:481(_ssl_wrap_socket_impl)
#         5    0.000    0.000    0.127    0.025 /Users/saraprice/anaconda3/lib/python3.11/ssl.py:511(wrap_socket)
#         5    0.000    0.000    0.127    0.025 /Users/saraprice/anaconda3/lib/python3.11/ssl.py:1018(_create)
#         5    0.000    0.000    0.127    0.025 /Users/saraprice/anaconda3/lib/python3.11/ssl.py:1372(do_handshake)
#         5    0.127    0.025    0.127    0.025 {method 'do_handshake' of '_ssl._SSLSocket' objects}
#      9769    0.016    0.000    0.126    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/google/protobuf/internal/well_known_types.py:172(GetCurrentTime)
#         1    0.001    0.001    0.126    0.126 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2980(_log_artifact)
#      4912    0.069    0.000    0.124    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/hook_points.py:473(get_caching_hooks)
#      9767    0.046    0.000    0.122    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1443(format_dict)
#     20224    0.025    0.000    0.119    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:255(convert_tokens_to_ids)
#      4884    0.067    0.000    0.119    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:124(step)
#        41    0.000    0.000    0.117    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1375(persistent_load)
#        41    0.000    0.000    0.117    0.003 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1351(load_tensor)
#   1116304    0.117    0.000    0.117    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fancy_einsum/__init__.py:123(<genexpr>)
#        41    0.116    0.003    0.116    0.003 {built-in method torch._C.get_storage_from_record}
#     20225    0.038    0.000    0.116    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1861(decode_example)
# 68535/68526    0.082    0.000    0.115    0.000 {method 'format' of 'str' objects}
#     39350    0.054    0.000    0.112    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/grad_mode.py:182(__init__)
#      5344    0.026    0.000    0.112    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformer_lens/utils.py:1022(__enter__)
#     14792    0.050    0.000    0.111    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/autograd/grad_mode.py:78(__enter__)
#         1    0.000    0.000    0.111    0.111 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:3048(_assert_can_log_artifact)
#         1    0.000    0.000    0.110    0.110 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:2177(_expected_type)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:210(wrapped_fn)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:94(__call__)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/apis/public.py:211(execute)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:48(execute)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:58(_get_result)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/gql_request.py:42(execute)
#         1    0.000    0.000    0.109    0.109 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:626(post)
# ...
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/formatting/formatting.py:211(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/ast.py:795(__copy__)
#         5    0.000    0.000    0.000    0.000 {function socket.detach at 0x100e9a0c0}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:194(add_probe_handle)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/yaml/parser.py:89(dispose)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/core.py:613(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of 'xxhash.xxh64' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:274(items)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1054(pad_token)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/errors/term.py:77(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/jupyter.py:53(quiet)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/gitdb/base.py:42(binsha)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:186(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/logging/__init__.py:428(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:204(_get_kwargs_from_urls)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:899(config)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/features/features.py:1346(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1837(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:692(finalize)
#         3    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/pickle.py:205(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/nn/modules/container.py:309(__len__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:44(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/multiprocessing/process.py:51(parent_process)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/yaml/scanner.py:690(check_document_start)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/yaml/composer.py:13(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:347(is_tf_available)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1520(details)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1020(eos_token)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/ast.py:777(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:107(_set_callback)
#         4    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/sentry_sdk/hub.py:700(inner)
#         4    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/logging/__init__.py:983(setFormatter)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/builder.py:173(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:319(<lambda>)
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/printer.py:276(emoji)
#         2    0.000    0.000    0.000    0.000 {method 'HasField' of 'google._upb._message.Message' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/__init__.py:110(_assert_is_user_process)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:467(description)
#         4    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:587(resolve_trust_remote_code)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/Documents/Research/MATS/git/mats_sae_training/sae_training/utils.py:19(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/sessions.py:453(__enter__)
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_settings.py:1343(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WIFSTOPPED}
#         4    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/traitlets/traitlets.py:1335(ignore)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/utils.py:213(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_settings.py:1504(freeze)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1033(step)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_summary.py:120(_set_update_callback)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/printer.py:270(name)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/reporting.py:69(error_lines)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/filelock.py:119(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'google._upb._message.RepeatedScalarContainer' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:699(_ensure_can_add)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/lexer.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:158(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/ast.py:17(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/printer.py:103(leave_NamedType)
#         2    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISFIFO}
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#         3    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:177(settings)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:2275(_ttl_duration_seconds_to_gql)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/gitdb/base.py:60(size)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/apis/public.py:611(client)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/configparser.py:364(before_get)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:668(convert_to_tensors)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/storage_handlers/tracking_handler.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/pyarrow/parquet/core.py:669(_get_column_indices)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/load.py:1109(<lambda>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/git/cmd.py:1287(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:110(_set_artifact_callback)
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedRandom' objects}
#         4    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/gzip.py:113(seekable)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/tqdm/std.py:1132(__enter__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/reporting.py:65(warning_lines)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py:938(_prepare_ex_iterable_for_iteration)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:579(distributed_id)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:587(incremental)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/vendor/graphql-core-1.1/wandb_graphql/language/printer.py:109(leave_NonNullType)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/mailbox.py:240(add_probe)
#         2    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/subprocess.py:1311(_on_error_fd_closer)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1818(__enter__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact_manifests/artifact_manifest_v1.py:81(<lambda>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/jupyter.py:46(maybe_display)
#         1    0.000    0.000    0.000    0.000 {function OpenFiles.__getitem__ at 0x16d92c0e0}
#         1    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/contextlib.py:543(__enter__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/requests/cookies.py:435(get_policy)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact_manifests/artifact_manifest_v1.py:11(version)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/sentry_sdk/envelope.py:183(inferred_content_type)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/builder.py:419(manual_download_instructions)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/formatting/formatting.py:225(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:481(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:281(encodings)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1101(bos_token)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1105(eos_token)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1117(pad_token)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/artifacts/artifact.py:583(distributed_id)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:113(_set_settings)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/service/service_sock.py:26(_get_sock_client)
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.waitstatus_to_exitcode}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/multiprocessing/context.py:213(_check_available)
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/datasets/utils/filelock.py:169(timeout)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /Users/saraprice/anaconda3/lib/python3.11/site-packages/torch/serialization.py:410(__exit__)
# 4882| MSE Loss 18.660 | L0 95.754: : 20000768it [20:11, 20932.50it/s]/Users/saraprice/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2163: UserWarning: Run (j2dqzyii) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),

# %% [markdown]
# # GPT2 - Small

# %%
import torch
import os 
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["WANDB__SERVICE_WAIT"] = "300"

from sae_training.config import LanguageModelSAERunnerConfig
from sae_training.lm_runner import language_model_sae_runner

cfg = LanguageModelSAERunnerConfig(

    # Data Generating Function (Model + Training Distibuion)
    model_name = "gpt2-small",
    hook_point = "blocks.10.hook_resid_pre",
    hook_point_layer = 11,
    d_in = 768,
    dataset_path = "Skylion007/openwebtext",
    is_dataset_tokenized=False,
    
    # SAE Parameters
    expansion_factor = 64, # determines the dimension of the SAE.
    
    # Training Parameters
    lr = 1e-5,
    l1_coefficient = 5e-4,
    lr_scheduler_name=None,
    train_batch_size = 4096,
    context_size = 128,
    
    # Activation Store Parameters
    n_batches_in_buffer = 128,
    total_training_tokens = 1_000_000 * 200, # 200M tokens seems doable overnight.
    store_batch_size = 32,
    
    # Resampling protocol
    feature_sampling_method = 'l2',
    feature_sampling_window = 1000,
    feature_reinit_scale = 0.2,
    dead_feature_window=5000,
    dead_feature_threshold = 1e-7,
    
    # WANDB
    log_to_wandb = True,
    wandb_project= "mats_sae_training_gpt2_small",
    wandb_entity = None,
    wandb_log_frequency=50,
    
    # Misc
    device = "mps",
    seed = 42,
    n_checkpoints = 5,
    checkpoint_path = "checkpoints",
    dtype = torch.float32,
    )

sparse_autoencoder = language_model_sae_runner(cfg)

# %% [markdown]
# # GPT2-Small Hook Q

# %%
import torch
import os 
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["WANDB__SERVICE_WAIT"] = "300"

from sae_training.config import LanguageModelSAERunnerConfig
from sae_training.lm_runner import language_model_sae_runner

cfg = LanguageModelSAERunnerConfig(

    # Data Generating Function (Model + Training Distibuion)
    model_name = "gpt2-small",
    hook_point = "blocks.10.attn.hook_q",
    hook_point_layer = 11,
    hook_point_head_index=7,
    d_in = 64,
    dataset_path = "Skylion007/openwebtext",
    is_dataset_tokenized=False,
    
    # SAE Parameters
    expansion_factor = 64, # determines the dimension of the SAE.
    
    # Training Parameters
    lr = 1e-3,
    l1_coefficient = 0.001,
    lr_scheduler_name=None,
    train_batch_size = 4096,
    context_size = 128,
    
    # Activation Store Parameters
    n_batches_in_buffer = 512,
    total_training_tokens = 1_000_000 * 3, # 200M tokens seems doable overnight.
    store_batch_size = 32,
    
    # Resampling protocol
    feature_sampling_method = 'l2',
    feature_sampling_window = 1000,
    feature_reinit_scale = 0.2,
    dead_feature_window=1000,
    dead_feature_threshold = 1e-7,
    
    # WANDB
    log_to_wandb = True,
    wandb_project= "mats_sae_training_gpt2_small_hook_q",
    wandb_entity = None,
    wandb_log_frequency=50,
    
    # Misc
    device = "mps",
    seed = 42,
    n_checkpoints = 5,
    checkpoint_path = "checkpoints",
    dtype = torch.float32,
    )

sparse_autoencoder = language_model_sae_runner(cfg)

# %%
sparse_autoencoder.save_model("./overnight_sae_resid_pre_10_gpt_2_small.pt")

# %% [markdown]
# # Pythia 70-M

# %%
import torch
import os 

from sae_training.config import LanguageModelSAERunnerConfig
from sae_training.lm_runner import language_model_sae_runner

import cProfile


os.environ["TOKENIZERS_PARALLELISM"] = "false"
cfg = LanguageModelSAERunnerConfig(

    # Data Generating Function (Model + Training Distibuion)
    model_name = "pythia-70m",
    hook_point = "blocks.0.hook_mlp_out",
    hook_point_layer = 0,
    d_in = 512,
    dataset_path = "EleutherAI/the_pile_deduplicated",
    is_dataset_tokenized=False,
    
    # SAE Parameters
    expansion_factor = 16,
    
    # Training Parameters
    lr = 3e-4,
    l1_coefficient = 1e-3,
    train_batch_size = 4096,
    context_size = 128,
    
    # Activation Store Parameters
    n_batches_in_buffer = 64,
    total_training_tokens = 1_000_000 * 5, 
    store_batch_size = 32,
    
    # Resampling protocol
    feature_sampling_method = 'l2',
    feature_sampling_window = 2500, # Doesn't currently matter.
    feature_reinit_scale = 0.2,
    dead_feature_window=1250,
    dead_feature_threshold = 1e-8,
    
    # WANDB
    log_to_wandb = True,
    wandb_project= "mats_sae_training_language_benchmark_tests",
    wandb_entity = None,
    wandb_log_frequency=10,
    
    # Misc
    device = "mps",
    seed = 42,
    n_checkpoints = 0,
    checkpoint_path = "checkpoints",
    dtype = torch.float32,
    )

def main():
    sparse_autoencoder = language_model_sae_runner(cfg)

main()
# os.environ["TOKENIZERS_PARALLELISM"] = "false"
# import cProfile, pstats, io
# from pstats import SortKey
# pr = cProfile.Profile()
# pr.enable()
# # ... do something ...
# main()
# pr.disable()
# s = io.StringIO()
# sortby = SortKey.CUMULATIVE
# ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
# ps.print_stats()
# print(s.getvalue())

# %% [markdown]
# # Tiny Stories

# %%
import torch
import os 

from sae_training.config import LanguageModelSAERunnerConfig
from sae_training.lm_runner import language_model_sae_runner



os.environ["TOKENIZERS_PARALLELISM"] = "false"
cfg = LanguageModelSAERunnerConfig(

    # Data Generating Function (Model + Training Distibuion)
    model_name = "tiny-stories-2L-33M",
    hook_point = "blocks.1.mlp.hook_post",
    hook_point_layer = 1,
    d_in = 4096,
    dataset_path = "roneneldan/TinyStories",
    is_dataset_tokenized=False,
    
    # SAE Parameters
    expansion_factor = 4,
    
    # Training Parameters
    lr = 1e-4,
    l1_coefficient = 3e-4,
    train_batch_size = 4096,
    context_size = 128,
    
    # Activation Store Parameters
    n_batches_in_buffer = 128,
    total_training_tokens = 1_000_000 * 10, # want 500M eventually.
    store_batch_size = 32,
    
    # Resampling protocol
    feature_sampling_method = 'l2',
    feature_sampling_window = 2500, # Doesn't currently matter.
    feature_reinit_scale = 0.2,
    dead_feature_window=1250,
    dead_feature_threshold = 0.0005,
    
    # WANDB
    log_to_wandb = True,
    wandb_project= "mats_sae_training_language_benchmark_tests",
    wandb_entity = None,
    wandb_log_frequency=10,
    
    # Misc
    device = "mps",
    seed = 42,
    n_checkpoints = 0,
    checkpoint_path = "checkpoints",
    dtype = torch.float32,
    )

sparse_autoencoder = language_model_sae_runner(cfg)

# %% [markdown]
# # Toy Model

# %%
from sae_training.toy_model_runner import SAEToyModelRunnerConfig, toy_model_sae_runner


cfg = SAEToyModelRunnerConfig(
    
    # Model Details
    n_features=200,
    n_hidden=5,
    n_correlated_pairs=0,
    n_anticorrelated_pairs=0,
    feature_probability=0.025,
    model_training_steps=10_000,
    
    # SAE Parameters
    d_sae=240,
    l1_coefficient=0.001,
    
    # SAE Train Config
    train_batch_size=1028,
    feature_sampling_window=3_000,
    dead_feature_window=1_000,
    feature_reinit_scale=0.5,
    total_training_tokens=4096*300,
    
    # Other parameters
    log_to_wandb=True,
    wandb_project="sae-training-test",
    wandb_log_frequency=5,
    device="mps",
)

trained_sae = toy_model_sae_runner(cfg)

assert trained_sae is not None
